# %% [markdown]
# # DataCollection

# %% [markdown]
# ## 1. Crawl data

# %%
import pandas as pd
import numpy as np
import re
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
from urllib.parse import urljoin, unquote

# %%
# Base URL
BASE_URL = "https://www.norbeck.nu/abc/"

# Entry page
start_url = urljoin(BASE_URL, "index.asp")

# List to store scraped data
data = []


def decode_misencoded_url(url):
    """ Fix URL encoding errors to ensure special characters (e.g., å) are correctly displayed """
    try:
        return url.encode('latin1').decode('utf-8')  # Fix 'Ã¥' -> 'å'
    except UnicodeEncodeError:
        return url  # If decoding fails, keep it as is
    except UnicodeDecodeError:
        return url  # Prevent program crashes


def get_links(url, css_selector):
    """
    Extract all links from a given webpage that match the specified CSS selector.
    :param url: The webpage URL to scrape
    :param css_selector: The CSS selector defining which <a> tags to extract
    :return: A list of tuples [(link text, full URL)]
    """
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
    except requests.exceptions.RequestException as e:
        print(f"Failed to fetch {url}: {e}")
        return []

    soup = BeautifulSoup(response.text, "html.parser")

    links = []
    for a_tag in soup.select(css_selector):  # Extract all matching <a> tags
        href = a_tag.get("href")
        text = a_tag.text.strip()
        if href and not href.startswith("#"):
            full_url = unquote(urljoin(BASE_URL, href))  # Decode URL
            full_url = decode_misencoded_url(full_url)  # Fix encoding issues
            links.append((text, full_url))

    return links


def crawl_tune_types():
    """
    Step 1: Scrape all tune type links from the "Irish Tunes," "Swedish Tunes," and "Other Tunes" sections.
    """
    tune_type_links = get_links(start_url, ".col-4.col-m-6 a")  # Get tune type links

    for first_text, first_link in tune_type_links:
        print(f"Processing: {first_text} ({first_link})")
        crawl_tunes(first_text, first_link)  # Proceed to the next level to scrape tune details


def crawl_tunes(first_text, tune_page_url):
    """
    Step 2: Scrape all tune detail links from the category pages.
    :param first_text: The text of the first-level link (e.g., "Jigs", "Reels")
    :param tune_page_url: The URL of the specific tune category page
    """
    tune_links = get_links(tune_page_url, ".col-9 a")  # Select tune links within the table

    for second_text, second_link in tune_links:
        crawl_tune_details(first_text, second_text, second_link)  # Proceed to the tune detail page


def crawl_tune_details(first_text, second_text, tune_detail_url):
    """
    Step 3: Scrape an individual tune detail page and extract the content inside <div id="abc">.
    :param first_text: The text of the first-level link (e.g., "Jigs", "Reels")
    :param second_text: The text of the second-level link (e.g., "The Blarney Pilgrim")
    :param tune_detail_url: The URL of the specific tune's page
    """
    try:
        tune_detail_url = decode_misencoded_url(unquote(tune_detail_url))  # Fix URL encoding issues
        response = requests.get(tune_detail_url, timeout=10)
        response.raise_for_status()

    except requests.exceptions.HTTPError as http_err:
        print(f"HTTPError: {http_err} - Skipping {tune_detail_url}")
        return

    except requests.exceptions.RequestException as req_err:
        print(f"RequestException: {req_err} - Skipping {tune_detail_url}")
        return

    # Parse HTML
    soup = BeautifulSoup(response.text, "html.parser")

    # Extract content from <div id="abc">
    abc_div = soup.find("div", {"id": "abc"})
    abc_content = abc_div.get_text(separator="\n").strip() if abc_div else "No ABC notation found"

    # Store data in the list
    data.append({
        "final_page_url": tune_detail_url,
        "first_page_text": first_text,
        "second_page_text": second_text,
        "abc_notation": abc_content
    })

# %%
# Start Crawling
crawl_tune_types()
# Out:
# Processing: airs (https://www.norbeck.nu/abc/index2.asp?cat=i&sort=number&rhythm=air&rhythm2=)
# Processing: barn dances (https://www.norbeck.nu/abc/index2.asp?cat=i&sort=number&rhythm=barndance&rhythm2=)
# Processing: carolan tunes (https://www.norbeck.nu/abc/index2.asp?cat=i&sort=number&rhythm=carolan&rhythm2=)
# Processing: country dances (https://www.norbeck.nu/abc/index2.asp?cat=i&sort=number&rhythm=country+dance&rhythm2=)
# Processing: highlands and flings (https://www.norbeck.nu/abc/index2.asp?cat=i&sort=number&rhythm=highland&rhythm2=fling)
# Processing: hornpipes (https://www.norbeck.nu/abc/index2.asp?cat=i&sort=number&rhythm=hornpipe&rhythm2=)
# Processing: jigs (https://www.norbeck.nu/abc/index2.asp?cat=i&sort=number&rhythm=jig&rhythm2=)
# Processing: marches (https://www.norbeck.nu/abc/index2.asp?cat=i&sort=number&rhythm=march&rhythm2=)
# Processing: mazurkas (https://www.norbeck.nu/abc/index2.asp?cat=i&sort=number&rhythm=mazurka&rhythm2=)
# Processing: polkas (https://www.norbeck.nu/abc/index2.asp?cat=i&sort=number&rhythm=polka&rhythm2=)
# Processing: reels (https://www.norbeck.nu/abc/index2.asp?cat=i&sort=number&rhythm=reel&rhythm2=)
# Processing: set dances (https://www.norbeck.nu/abc/index2.asp?cat=i&sort=number&rhythm=set+dance&rhythm2=)
# Processing: slides and single jigs (https://www.norbeck.nu/abc/index2.asp?cat=i&sort=number&rhythm=slide&rhythm2=single+jig)
# Processing: slip jigs and hop jigs (https://www.norbeck.nu/abc/index2.asp?cat=i&sort=number&rhythm=slip+jig&rhythm2=hop+jig)
# Processing: slow airs (https://www.norbeck.nu/abc/index2.asp?cat=i&sort=number&rhythm=slow+air&rhythm2=)
# Processing: songs (https://www.norbeck.nu/abc/index2.asp?cat=i&sort=number&rhythm=song&rhythm2=)
# Processing: strathspeys (https://www.norbeck.nu/abc/index2.asp?cat=i&sort=number&rhythm=strathspey&rhythm2=)
# Processing: waltzes (https://www.norbeck.nu/abc/index2.asp?cat=i&sort=number&rhythm=waltz&rhythm2=)
# Processing: gånglåtar (https://www.norbeck.nu/abc/index2.asp?cat=s&sort=number&rhythm=gånglåt&rhythm2=)
# Processing: hallingar (https://www.norbeck.nu/abc/index2.asp?cat=s&sort=number&rhythm=halling&rhythm2=)
# Processing: jämna polskor (https://www.norbeck.nu/abc/index2.asp?cat=s&sort=number&rhythm=polska+J&rhythm2=)
# Processing: polskor kort etta (https://www.norbeck.nu/abc/index2.asp?cat=s&sort=number&rhythm=polska+K1&rhythm2=)
# Processing: polskor lång etta (https://www.norbeck.nu/abc/index2.asp?cat=s&sort=number&rhythm=polska+L1&rhythm2=)
# Processing: ojämna polskor (https://www.norbeck.nu/abc/index2.asp?cat=s&sort=number&rhythm=polska+O&rhythm2=)
# Processing: schottisar (https://www.norbeck.nu/abc/index2.asp?cat=s&sort=number&rhythm=schottis&rhythm2=reiländer)
# Processing: slängpolskor (https://www.norbeck.nu/abc/index2.asp?cat=s&sort=number&rhythm=slängpolska&rhythm2=)
# Processing: sånger (https://www.norbeck.nu/abc/index2.asp?cat=s&sort=number&rhythm=sång&rhythm2=)
# Processing: valser (https://www.norbeck.nu/abc/index2.asp?cat=s&sort=number&rhythm=vals&rhythm2=)
# Processing: an dro (https://www.norbeck.nu/abc/index2.asp?cat=m&sort=number&rhythm=an+dro&rhythm2=)
# Processing: bourrée (https://www.norbeck.nu/abc/index2.asp?cat=m&sort=number&rhythm=bourree&rhythm2=)
# Processing: buchimish (https://www.norbeck.nu/abc/index2.asp?cat=m&sort=number&rhythm=buchimish&rhythm2=)
# Processing: cadaneasca (https://www.norbeck.nu/abc/index2.asp?cat=m&sort=number&rhythm=cadaneasca&rhythm2=)
# Processing: frailach (https://www.norbeck.nu/abc/index2.asp?cat=m&sort=number&rhythm=frailach&rhythm2=)
# Processing: gavottes (https://www.norbeck.nu/abc/index2.asp?cat=m&sort=number&rhythm=gavotte&rhythm2=)
# Processing: geampara (https://www.norbeck.nu/abc/index2.asp?cat=m&sort=number&rhythm=geampara&rhythm2=)
# Processing: hanter dro (https://www.norbeck.nu/abc/index2.asp?cat=m&sort=number&rhythm=hanter+dro&rhythm2=)
# Processing: hora (https://www.norbeck.nu/abc/index2.asp?cat=m&sort=number&rhythm=hora&rhythm2=)
# Processing: kolo (https://www.norbeck.nu/abc/index2.asp?cat=m&sort=number&rhythm=kolo&rhythm2=)
# Processing: kopanitsa (https://www.norbeck.nu/abc/index2.asp?cat=m&sort=number&rhythm=kopanitsa&rhythm2=)
# Processing: miscellaneous (https://www.norbeck.nu/abc/index2.asp?cat=m&sort=number&rhythm=misc&rhythm2=)
# Processing: muineiras (https://www.norbeck.nu/abc/index2.asp?cat=m&sort=number&rhythm=muineira&rhythm2=)
# Processing: paidushko horo (https://www.norbeck.nu/abc/index2.asp?cat=m&sort=number&rhythm=paidushko+horo&rhythm2=)
# Processing: rachenitsa (https://www.norbeck.nu/abc/index2.asp?cat=m&sort=number&rhythm=rachenitsa&rhythm2=)
# Processing: ridée (https://www.norbeck.nu/abc/index2.asp?cat=m&sort=number&rhythm=ridee&rhythm2=)
# Processing: rond (https://www.norbeck.nu/abc/index2.asp?cat=m&sort=number&rhythm=rond&rhythm2=)
# Processing: sandansko horo (https://www.norbeck.nu/abc/index2.asp?cat=m&sort=number&rhythm=sandansko+horo&rhythm2=)
# Processing: smeseno horo (https://www.norbeck.nu/abc/index2.asp?cat=m&sort=number&rhythm=smeseno+horo&rhythm2=krivo+sadovsko+horo)
# Processing: valse musette (https://www.norbeck.nu/abc/index2.asp?cat=m&sort=number&rhythm=valse+musette&rhythm2=)
# Processing: wayñu (https://www.norbeck.nu/abc/index2.asp?cat=m&sort=number&rhythm=waynu&rhythm2=)

# %%
# Store into DataFrame
df = pd.DataFrame(data, columns=["final_page_url", "first_page_text", "second_page_text", "abc_notation"])
# Out:
#                                          final_page_url first_page_text  \
# 0     https://www.norbeck.nu/abc/display.asp?rhythm=...            airs
# 1     https://www.norbeck.nu/abc/display.asp?rhythm=...            airs
# 2     https://www.norbeck.nu/abc/display.asp?rhythm=...            airs
# 3     https://www.norbeck.nu/abc/display.asp?rhythm=...            airs
# 4     https://www.norbeck.nu/abc/display.asp?rhythm=...            airs
# ...                                                 ...             ...
# 4701  https://www.norbeck.nu/abc/display.asp?rhythm=...           wayñu
# 4702  https://www.norbeck.nu/abc/display.asp?rhythm=...           wayñu
# 4703  https://www.norbeck.nu/abc/display.asp?rhythm=...           wayñu
# 4704  https://www.norbeck.nu/abc/display.asp?rhythm=...           wayñu
# 4705  https://www.norbeck.nu/abc/display.asp?rhythm=...           wayñu
#
#                 second_page_text  \
# 0                  Down the Hill
# 1           Eagle's Whistle, The
# 2                 Fead an Iolair
# 3              O'Donovan's March
# 4             Gol na mBan san Ár
# ...                          ...
# 4701                 Ojos Azules
# 4702  A las orillas del Titicaca
# 4703               Dos Palomitas
# 4704                   Saririway
# 4705                 Chunguinada
#
#                                            abc_notation
# 0     X:1\n\nT:Down the Hill\n\nR:\nair\n\nH:Origina...
# 1     X:2\n\nT:Eagle's Whistle, The\n\nT:Fead an Iol...
# 2     X:2\n\nT:Eagle's Whistle, The\n\nT:Fead an Iol...
# 3     X:2\n\nT:Eagle's Whistle, The\n\nT:Fead an Iol...
# 4     X:2\n\nT:Eagle's Whistle, The\n\nT:Fead an Iol...
# ...                                                 ...
# 4701  X:18\n\nT:Ojos Azules\n\nR:\nwaynu\n\nO:Peru\n...
# 4702  X:19\n\nT:A las orillas del Titicaca\n\nR:\nwa...
# 4703  X:20\n\nT:Dos Palomitas\n\nR:\nwaynu\n\nO:Arge...
# 4704  X:21\n\nT:Saririway\n\nR:\nwaynu\n\nH:The firs...
# 4705  X:22\n\nT:Chunguinada\n\nR:\nwaynu\n\nO:Peru\n...
#
# [4706 rows x 4 columns]

# %%
df.drop_duplicates(subset='final_page_url',inplace=True)
df.reset_index(inplace=True,drop=True)
df
# Out:
#                                          final_page_url first_page_text  \
# 0     https://www.norbeck.nu/abc/display.asp?rhythm=...            airs
# 1     https://www.norbeck.nu/abc/display.asp?rhythm=...            airs
# 2     https://www.norbeck.nu/abc/display.asp?rhythm=...            airs
# 3     https://www.norbeck.nu/abc/display.asp?rhythm=...            airs
# 4     https://www.norbeck.nu/abc/display.asp?rhythm=...            airs
# ...                                                 ...             ...
# 3324  https://www.norbeck.nu/abc/display.asp?rhythm=...           wayñu
# 3325  https://www.norbeck.nu/abc/display.asp?rhythm=...           wayñu
# 3326  https://www.norbeck.nu/abc/display.asp?rhythm=...           wayñu
# 3327  https://www.norbeck.nu/abc/display.asp?rhythm=...           wayñu
# 3328  https://www.norbeck.nu/abc/display.asp?rhythm=...           wayñu
#
#                 second_page_text  \
# 0                  Down the Hill
# 1           Eagle's Whistle, The
# 2            Tabhair dom do lámh
# 3                An Rogaire Dubh
# 4                 Molly MacAlpin
# ...                          ...
# 3324                 Ojos Azules
# 3325  A las orillas del Titicaca
# 3326               Dos Palomitas
# 3327                   Saririway
# 3328                 Chunguinada
#
#                                            abc_notation
# 0     X:1\n\nT:Down the Hill\n\nR:\nair\n\nH:Origina...
# 1     X:2\n\nT:Eagle's Whistle, The\n\nT:Fead an Iol...
# 2     X:3\n\nT:Tabhair dom do lámh\n\nT:Give Me Your...
# 3     X:4\n\nT:An Rogaire Dubh\n\nT:Black Rogue, The...
# 4     X:5\n\nT:Molly MacAlpin\n\nT:Carolan's Dream\n...
# ...                                                 ...
# 3324  X:18\n\nT:Ojos Azules\n\nR:\nwaynu\n\nO:Peru\n...
# 3325  X:19\n\nT:A las orillas del Titicaca\n\nR:\nwa...
# 3326  X:20\n\nT:Dos Palomitas\n\nR:\nwaynu\n\nO:Arge...
# 3327  X:21\n\nT:Saririway\n\nR:\nwaynu\n\nH:The firs...
# 3328  X:22\n\nT:Chunguinada\n\nR:\nwaynu\n\nO:Peru\n...
#
# [3329 rows x 4 columns]

# %%
# df.to_csv('Data//abc_tunes.csv',encoding='utf-8-sig',index=False)

# %%
import pandas as pd

def parse_abc_notation(abc_string):
    """
    Parses a single ABC notation string and stores the data in a dictionary (without using regular expressions).
    :param abc_string: A string containing ABC notation.
    :return: A dictionary.
    """
    # Define the supported fields (in order)
    fields = ["X", "S", "T", "R", "B", "H", "O", "D", "Z", "C", "M", "L", "Q", "W", "K", "Notes"]
    data = {key: [] for key in fields}  # Store parsed data
    last_key = None  # Keep track of the previous field
    
    # Split different sections by "\n\n"
    sections = abc_string.strip().split("\n\n")
    
    for section in sections:
        lines = section.split("\n")  # Split by lines
        for line in lines:
            line = line.strip()
            if not line:
                continue  # Skip empty lines
            
            # Check if the line matches a known field
            key_value = line.split(":", 1)
            if len(key_value) == 2 and key_value[0] in fields:
                key, value = key_value
                key = key.strip()
                value = value.strip()
                
                if key == "K":  # Special handling for the "K" field: first line goes to "K", following lines to "Notes"
                    data["K"].append(value)
                    last_key = "Notes"  # Assign subsequent content to "Notes"
                else:
                    data[key].append(value)
                    last_key = key  # Update the current field
            else:
                # If the line has no field prefix, append it to the previous field
                if last_key:
                    if not data[last_key]:  # Avoid index error
                        data[last_key].append(line.strip())
                    else:
                        data[last_key][-1] += " " + line.strip()
    
    # Merge multiple values into a single string (joined by " ")
    for key in fields:
        data[key] = " ".join(data[key]) if data[key] else None

    return data  # Return dictionary, which can be converted to a DataFrame

# %%
parsed_df = df["abc_notation"].apply(parse_abc_notation).apply(pd.Series)
df_final = pd.concat([df, parsed_df], axis=1)
df_final.drop(['first_page_text','second_page_text'],inplace=True,axis=1)
df_final
# Out:
#                                          final_page_url  \
# 0     https://www.norbeck.nu/abc/display.asp?rhythm=...
# 1     https://www.norbeck.nu/abc/display.asp?rhythm=...
# 2     https://www.norbeck.nu/abc/display.asp?rhythm=...
# 3     https://www.norbeck.nu/abc/display.asp?rhythm=...
# 4     https://www.norbeck.nu/abc/display.asp?rhythm=...
# ...                                                 ...
# 3324  https://www.norbeck.nu/abc/display.asp?rhythm=...
# 3325  https://www.norbeck.nu/abc/display.asp?rhythm=...
# 3326  https://www.norbeck.nu/abc/display.asp?rhythm=...
# 3327  https://www.norbeck.nu/abc/display.asp?rhythm=...
# 3328  https://www.norbeck.nu/abc/display.asp?rhythm=...
#
#                                            abc_notation   X  \
# 0     X:1\n\nT:Down the Hill\n\nR:\nair\n\nH:Origina...   1
# 1     X:2\n\nT:Eagle's Whistle, The\n\nT:Fead an Iol...   2
# 2     X:3\n\nT:Tabhair dom do lámh\n\nT:Give Me Your...   3
# 3     X:4\n\nT:An Rogaire Dubh\n\nT:Black Rogue, The...   4
# 4     X:5\n\nT:Molly MacAlpin\n\nT:Carolan's Dream\n...   5
# ...                                                 ...  ..
# 3324  X:18\n\nT:Ojos Azules\n\nR:\nwaynu\n\nO:Peru\n...  18
# 3325  X:19\n\nT:A las orillas del Titicaca\n\nR:\nwa...  19
# 3326  X:20\n\nT:Dos Palomitas\n\nR:\nwaynu\n\nO:Arge...  20
# 3327  X:21\n\nT:Saririway\n\nR:\nwaynu\n\nH:The firs...  21
# 3328  X:22\n\nT:Chunguinada\n\nR:\nwaynu\n\nO:Peru\n...  22
#
#                                          S  \
# 0                                     None
# 1                                       EB
# 2                                     None
# 3     Sean Ryan and Ciara Ryan on Clare FM
# 4                                     None
# ...                                    ...
# 3324                                  None
# 3325                                  None
# 3326                                  None
# 3327                                  None
# 3328                                  None
#
#                                                       T       R  \
# 0                                         Down the Hill     air
# 1     Eagle's Whistle, The Fead an Iolair O'Donovan'...     air
# 2     Tabhair dom do lámh Give Me Your Hand Da Mihi ...     air
# 3     An Rogaire Dubh Black Rogue, The Did You See t...     air
# 4                        Molly MacAlpin Carolan's Dream     air
# ...                                                 ...     ...
# 3324                                        Ojos Azules   waynu
# 3325                         A las orillas del Titicaca   waynu
# 3326                                      Dos Palomitas   waynu
# 3327                                          Saririway   waynu
# 3328                                        Chunguinada   waynu
#
#                                       B  \
# 0                                  None
# 1     Roche Collection, vol. 2, No. 321
# 2                                  None
# 3            Bunting 1840 (in key of A)
# 4                                  None
# ...                                 ...
# 3324                               None
# 3325                               None
# 3326                               None
# 3327                               None
# 3328                               None
#
#                                                       H             O  \
# 0     Originally in Gdor and notated in 6/8 time. Ve...          None
# 1     See also march#16. The Irish title means "Lame...          None
# 2                                                  None          None
# 3                                                  None          None
# 4     This was one of Turlough O'Carolan's favourite...          None
# ...                                                 ...           ...
# 3324                                               None          Peru
# 3325                                               None  Peru/Bolivia
# 3326                                               None     Argentina
# 3327          The first verse is in the Aymará language       Bolivia
# 3328                                               None          Peru
#
#               D               Z  \
# 0          None     id:hn-air-1
# 1          None     id:hn-air-2
# 2          None     id:hn-air-3
# 3          None     id:hn-air-4
# 4          None     id:hn-air-5
# ...         ...             ...
# 3324       None  id:hn-waynu-18
# 3325  Los Incas  id:hn-waynu-19
# 3326       None  id:hn-waynu-20
# 3327       None  id:hn-waynu-21
# 3328       None  id:hn-waynu-22
#
#                                                       C    M    L        Q  \
# 0                                                  None  3/4  1/8  1/4=160
# 1                                                  None  3/4  1/8  1/4=100
# 2      Ruaidhrí Dall Ó Catháin (c. 1570 - 1650 or 1653)  3/4  1/8  1/4=160
# 3                                                  None  3/4  1/8  1/4=160
# 4     William (Laurence) Connellan (c. 1645 - c. 170...   C|  1/8   1/2=50
# ...                                                 ...  ...  ...      ...
# 3324                                               None  2/4  1/8   1/4=90
# 3325                                               None  3/4  1/8   1/4=90
# 3326                                               None  2/4  1/8   1/4=90
# 3327                                               None  3/4  1/8   1/4=90
# 3328                                               None  2/4  1/8   1/4=90
#
#                                                       W     K  \
# 0                                                  None  Ador
# 1                                                  None     G
# 2                                                  None     G
# 3                                                  None     G
# 4                                                  None    Am
# ...                                                 ...   ...
# 3324  Ojos azules, no llores, No llores ni te enamor...    Em
# 3325  |: A las orillas del Titicaca :| |: grabé tu n...    Em
# 3326  Dos palomitas se lamentaban llorando y la una ...    Em
# 3327  Saririway sarjamiway, viditay, qhipaririwa jac...    Em
# 3328                                               None    Em
#
#                                                   Notes
# 0     BAG | E2A2A2 | A3EAB | cBABcA | BAGABG | AGEDE...
# 1     GA | B2 dB AG | B{c}B dB AG | A2 {c}AB AG | A2...
# 2     D2 | E2G2G2 | G4D2 | E2G2G2 | G4D2 | E2G2G2 | ...
# 3     D2 | G3ABG | A2B2d2 | G2A2B2 | d4g2 | G3ABG | ...
# 4     |: AB | c2 A>A A2 GA | dc A>G G2 cd | e2de dcA...
# ...                                                 ...
# 3324  BB Bd | B2 GA |[M:3/4] B2 GA BB |[M:2/4] A2 FG...
# 3325  B/BB/ e2 g2 | e/dB/ d2 e2 | G/GG/ e2 g2 | e/dB...
# 3326  G/GF/ GA | B/BA/ BB | e2 d2 | B4 | B/ed/ BA | ...
# 3327  B/BB/ c/ccc/B |[M:2/4] cd e/ee/ | B/BBG/E | [M...
# 3328  E/GB/ | e3g | ed dB | d/eg/ ed |1 B4- | B2 :|2...
#
# [3329 rows x 18 columns]

# %%
column_descriptions = {"X":"Index Number",
        "S":"Source",
        "R":"Rhythm(type)",
        "O":"Origin",
        "Z":"Id",
        "M":"Meter",
        "L":"Unit Note Length",
        "K":"Key",
        "Q":"Tempo",
        "H":"History",
        "T":"Title",
        "C":"Composer",
        "W":"Lyrics",
        "B":"Bibliography",
        "D":"Discography"
        }

# %%
# Calculate the missing values
missing_values = df_final.isnull().sum()

# Create a DataFrame to display missing values with descriptions
missing_values_df = pd.DataFrame({
    "Column": missing_values.index,
    "Description": [column_descriptions.get(col, "") for col in missing_values.index],
    "Missing Values": missing_values.values,
    "Values": df_final.shape[0] - missing_values.values
})

missing_values_df
# Out:
#             Column       Description  Missing Values  Values
# 0   final_page_url                                 0    3329
# 1     abc_notation                                 0    3329
# 2                X      Index Number               0    3329
# 3                S            Source            3072     257
# 4                T             Title               0    3329
# 5                R      Rhythm(type)               0    3329
# 6                B      Bibliography            3169     160
# 7                H           History            1809    1520
# 8                O            Origin            2698     631
# 9                D       Discography            1887    1442
# 10               Z                Id               7    3322
# 11               C          Composer            2631     698
# 12               M             Meter               1    3328
# 13               L  Unit Note Length            1563    1766
# 14               Q             Tempo            2897     432
# 15               W            Lyrics            3063     266
# 16               K               Key               0    3329
# 17           Notes                                 0    3329

# %%
df_final.to_csv('Data//abc_tunes.csv',index=False,encoding='utf-8-sig')
